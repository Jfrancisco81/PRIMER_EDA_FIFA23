# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))
os.chdir(os.path.dirname(sys.path[0])) # Este comando hace que el notebook sea la ruta principal y poder trabajar en cascada

# %%
from utils.funcion import *

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
jugadores = pd.read_csv('../jugadores/src/data/raw/players_fifa23.csv')

# %%
jugadores.head()
# Out:
#        ID            Name            FullName  Age  Height  Weight  \
# 0  158023        L. Messi        Lionel Messi   35     169      67
# 1  165153      K. Benzema       Karim Benzema   34     185      81
# 2  188545  R. Lewandowski  Robert Lewandowski   33     185      81
# 3  192985    K. De Bruyne     Kevin De Bruyne   31     181      70
# 4  231747       K. Mbappé       Kylian Mbappé   23     182      73
#
#                                            PhotoUrl Nationality  Overall  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   Argentina       91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png      France       91
# 2  https://cdn.sofifa.net/players/188/545/23_60.png      Poland       91
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium       91
# 4  https://cdn.sofifa.net/players/231/747/23_60.png      France       91
#
#    Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating RWBRating  \
# ...

# %%
jugadores.shape
# Out:
# (18539, 90)

# %%
jugadores.describe()
# Out:
#                   ID           Age        Height        Weight       Overall  \
# count   18539.000000  18539.000000  18539.000000  18539.000000  18539.000000
# mean   237011.899725     25.240412    181.550839     75.173904     65.852042
# std     26714.860353      4.718163      6.858097      7.013593      6.788353
# min      1179.000000     16.000000    155.000000     49.000000     47.000000
# 25%    221663.000000     21.000000    177.000000     70.000000     62.000000
# 50%    241195.000000     25.000000    182.000000     75.000000     66.000000
# 75%    259059.000000     29.000000    186.000000     80.000000     70.000000
# max    271817.000000     44.000000    206.000000    105.000000     91.000000
#
#           Potential        Growth    TotalStats     BaseStats      ValueEUR  \
# count  18539.000000  18539.000000  18539.000000  18539.000000  1.853900e+04
# mean      71.016668      5.164626   1602.114569    357.946221  2.875461e+06
# ...

# %%
jugadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 18539 non-null  int64
#  1   Name               18539 non-null  object
#  2   FullName           18539 non-null  object
#  3   Age                18539 non-null  int64
#  4   Height             18539 non-null  int64
#  5   Weight             18539 non-null  int64
#  6   PhotoUrl           18539 non-null  object
#  7   Nationality        18539 non-null  object
#  8   Overall            18539 non-null  int64
#  9   Potential          18539 non-null  int64
#  10  Growth             18539 non-null  int64
#  11  TotalStats         18539 non-null  int64
#  12  BaseStats          18539 non-null  int64
#  13  Positions          18539 non-null  object
#  14  BestPosition       18539 non-null  object
#  15  Club               18539 non-null  object
# ...

# %%
# Seleccionar las filas que corresponden a porteros
porteros = jugadores.loc[jugadores['Positions'] == 'GK']
porteros_copy = porteros.copy()
porteros_copy = eliminar_columnas(porteros_copy,porteros_columnas)
porteros_copy.sort_values('Overall',ascending=False).head()
# Out:
#            Name  Age  Height  Weight Nationality  Overall  Potential  \
# 6   T. Courtois   30     199      96     Belgium       90         91
# 7      M. Neuer   36     193      93     Germany       90         90
# 14     J. Oblak   29     188      87    Slovenia       89         91
# 16      Ederson   28     188      86      Brazil       89         91
# 18      Alisson   29     191      91      Brazil       89         90
#
#                   Club  ValueEUR  WeakFoot  PaceTotal  DefendingTotal  \
# 6       Real Madrid CF  90000000         3         84              46
# 7    FC Bayern München  13500000         4         87              56
# 14  Atlético de Madrid  85500000         3         86              49
# 16     Manchester City  88000000         3         87              64
# 18           Liverpool  79000000         3         86              54
#
#     PhysicalityTotal  Crossing  LongPassing  BallControl  Acceleration  \
# ...

# %%
# Guardamos los datos de los porteros
porteros_copy.to_csv('../jugadores/src/data/processed/arqueros.csv')

# %%
# Seleccionar las filas que corresponden a porteros
porteros = jugadores.loc[jugadores['Positions'] == 'GK']

# Eliminar las filas de los porteros del DataFrame original
jugadores = jugadores.drop(porteros.index)

# %%
# Utilizamos una función 
# Eliminammos las columnas que no vas a utilizar 
jugadores1 = eliminar_columnas(jugadores,columnas_borradas)

# %%
jugadores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16478 entries, 0 to 18538
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              16478 non-null  object
#  1   Age               16478 non-null  int64
#  2   Height            16478 non-null  int64
#  3   Weight            16478 non-null  int64
#  4   Nationality       16478 non-null  object
#  5   Overall           16478 non-null  int64
#  6   Potential         16478 non-null  int64
#  7   Club              16478 non-null  object
#  8   ValueEUR          16478 non-null  int64
#  9   PreferredFoot     16478 non-null  object
#  10  PaceTotal         16478 non-null  int64
#  11  ShootingTotal     16478 non-null  int64
#  12  PassingTotal      16478 non-null  int64
#  13  DribblingTotal    16478 non-null  int64
#  14  DefendingTotal    16478 non-null  int64
#  15  PhysicalityTotal  16478 non-null  int64
# ...

# %% [markdown]
# ### Traducción del nombre de las columnas
# El nombre de las columnas están en Ingles, por lo tanto buscamos la traducción y las renombramos en castellano. También imprimimos las primeras cinco filas para ver si esto había quedado bien.

# %%
# Utilizamos una función para realizar el cambio de nombre en las columnas 

jugadores1 = cambiar_Nombres(jugadores1,renombrar_columnas)
jugadores1.head(5)
# Out:
#            Nombre  Edad  altura  peso Nacionalidad  General  potencia  \
# 0        L. Messi    35     169    67    Argentina       91        91
# 1      K. Benzema    34     185    81       France       91        91
# 2  R. Lewandowski    33     185    81       Poland       91        91
# 3    K. De Bruyne    31     181    70      Belgium       91        91
# 4       K. Mbappé    23     182    73       France       91        95
#
#                   Club      Valor pie_habil  ritmo  disparo  total_pases  \
# 0  Paris Saint-Germain   54000000      Left     81       89           90
# 1       Real Madrid CF   64000000     Right     80       88           83
# 2         FC Barcelona   84000000     Right     75       91           79
# 3      Manchester City  107500000     Right     74       88           93
# 4  Paris Saint-Germain  190500000     Right     97       89           80
#
#    regate  defensa  fisico  finalización  precision_cabeza  volea  \
# ...

# %%
jugadores1.shape
# Out:
# (16478, 35)

# %%
#Utilizamos capitalize para que cada primera letra de las columnas esten en mayuscula 
jugadores1 = jugadores1.rename(columns=lambda x: x.capitalize())
jugadores1.head()
# Out:
#            Nombre  Edad  Altura  Peso Nacionalidad  General  Potencia  \
# 0        L. Messi    35     169    67    Argentina       91        91
# 1      K. Benzema    34     185    81       France       91        91
# 2  R. Lewandowski    33     185    81       Poland       91        91
# 3    K. De Bruyne    31     181    70      Belgium       91        91
# 4       K. Mbappé    23     182    73       France       91        95
#
#                   Club      Valor Pie_habil  Ritmo  Disparo  Total_pases  \
# 0  Paris Saint-Germain   54000000      Left     81       89           90
# 1       Real Madrid CF   64000000     Right     80       88           83
# 2         FC Barcelona   84000000     Right     75       91           79
# 3      Manchester City  107500000     Right     74       88           93
# 4  Paris Saint-Germain  190500000     Right     97       89           80
#
#    Regate  Defensa  Fisico  Finalización  Precision_cabeza  Volea  \
# ...

# %%
# eliminar los espacios en blanco que puedan estar al principio o 
# al final de la cadena de caracteres en la columna
jugadores1['Nombre'] = jugadores1['Nombre'].str.strip()
jugadores1['Pie_habil'] = jugadores1['Pie_habil'].str.strip()
jugadores1['Club'] = jugadores1['Club'].str.strip()
jugadores1['Nacionalidad'] = jugadores1['Nacionalidad'].str.strip()

# %%
# Eliminamos los duplicados si existen 
jugadores1 = jugadores1.drop_duplicates()

# %%
# verificamos si tenemos datos nulos 
jugadores1.isnull().sum()
# Out:
# Nombre              0
# Edad                0
# Altura              0
# Peso                0
# Nacionalidad        0
# General             0
# Potencia            0
# Club                0
# Valor               0
# Pie_habil           0
# Ritmo               0
# Disparo             0
# Total_pases         0
# Regate              0
# Defensa             0
# Fisico              0
# Finalización        0
# Precision_cabeza    0
# Volea               0
# Control_balon       0
# Aceleracion         0
# Sprint              0
# Agilidad            0
# Reaccion            0
# Balance             0
# Potencia_disparo    0
# Salto               0
# Resistencia         0
# Fuerza              0
# Tiros_largos        0
# Agrecion            0
# Intercepciones      0
# Posicionamiento     0
# Vision              0
# Penaltis            0
# dtype: int64

# %%
# Guardamos los datos

# %%
# jugadores_2 = jugadores1[['nombre','altura','nacionalidad','potencia',
#                           'club','pie_habil','disparo','total_pases',
#                           'regate','finalización','presicion_cabeza',
#                           'control_balon','sprint','reaccion','potencia_disparo',
#                           'salto','tiros_largos','Posicionamiento']]

# %%
# jugadores_2['nombre'] = jugadores_2['nombre'].str.strip()
# jugadores_2['pie_habil'] = jugadores_2['pie_habil'].str.strip()
# jugadores_2['club'] = jugadores_2['club'].str.strip()
# jugadores_2['nacionalidad'] = jugadores_2['nacionalidad'].str.strip()

# %%
jugadores_2.head()
# Out:
#            nombre  altura nacionalidad  potencia                 club  \
# 0        L. Messi     169    Argentina        91  Paris Saint-Germain
# 1      K. Benzema     185       France        91       Real Madrid CF
# 2  R. Lewandowski     185       Poland        91         FC Barcelona
# 3    K. De Bruyne     181      Belgium        91      Manchester City
# 4       K. Mbappé     182       France        95  Paris Saint-Germain
#
#   pie_habil  disparo  total_pases  regate  finalización  presicion_cabeza  \
# 0      Left       89           90      94            90                70
# 1     Right       88           83      87            92                90
# 2     Right       91           79      86            94                91
# 3     Right       88           93      87            85                55
# 4     Right       89           80      92            93                72
#
#    control_balon  sprint  reaccion  potencia_disparo  salto  tiros_largos  \
# ...

# %%
jugadores1.to_csv("../jugadores/src/data/processed/jugadores1.csv", index=False)

# %%
sns.set(style="white")
sns.lmplot(data=fifa23,x='REGATE',y='FINALIZACIÓN')

# %%
jugadores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18420 entries, 0 to 18538
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nombre            18420 non-null  object
#  1   edad              18420 non-null  int64
#  2   altura            18420 non-null  int64
#  3   peso              18420 non-null  int64
#  4   nacionalidad      18420 non-null  object
#  5   potencia          18420 non-null  int64
#  6   club              18420 non-null  object
#  7   pie_habil         18420 non-null  object
#  8   ritmo             18420 non-null  int64
#  9   disparo           18420 non-null  int64
#  10  total_pases       18420 non-null  int64
#  11  regate            18420 non-null  int64
#  12  defensa           18420 non-null  int64
#  13  fisico            18420 non-null  int64
#  14  finalización      18420 non-null  int64
#  15  presicion_cabeza  18420 non-null  int64
# ...

# %%
df_sprint = jugadores_2.sort_values('sprint',ascending=False)

# %%
sprint_10 = df_sprint.head(10)

# %%
sprint_10
# Out:
#              nombre  altura nacionalidad  potencia                     club  \
# 4         K. Mbappé     182       France        95      Paris Saint-Germain
# 651    Adama Traoré     178        Spain        80  Wolverhampton Wanderers
# 10327     S. Conteh     178      Germany        66          SC Paderborn 07
# 1283   J. St. Juste     186  Netherlands        80              Sporting CP
# 892        D. James     171        Wales        82                   Fulham
# 1186      S. Becker     180     Suriname        77       1. FC Union Berlin
# 63     Vinícius Jr.     176       Brazil        92           Real Madrid CF
# 2069    G. Holtmann     185  Philippines        74          VfL Bochum 1848
# 906         I. Sarr     185      Senegal        83                  Watford
# 21       E. Haaland     195       Norway        94          Manchester City
#
#       pie_habil  disparo  total_pases  regate  finalización  presicion_cabeza  \
# ...

# %%
jugadores_2.describe()
# Out:
#              altura      potencia       disparo   total_pases        regate  \
# count  18420.000000  18420.000000  18420.000000  18420.000000  18420.000000
# mean     181.550814     70.963301     53.732030     57.967264     63.054669
# std        6.855181      6.170634     13.609596      9.704352      9.324139
# min      155.000000     48.000000     16.000000     25.000000     28.000000
# 25%      177.000000     67.000000     44.000000     52.000000     58.000000
# 50%      182.000000     71.000000     56.000000     58.000000     64.000000
# 75%      186.000000     75.000000     64.000000     64.000000     69.000000
# max      206.000000     95.000000     92.000000     93.000000     94.000000
#
#        finalización  presicion_cabeza  control_balon        sprint  \
# count  18420.000000      18420.000000   18420.000000  18420.000000
# mean      46.200597         51.788056      58.450760     64.789468
# std       19.607819         17.306326      16.582193     15.103234
# ...

# %%
jugadores_2.isnull()
# Out:
#        nombre  altura  nacionalidad  potencia   club  pie_habil  disparo  \
# 0       False   False         False     False  False      False    False
# 1       False   False         False     False  False      False    False
# 2       False   False         False     False  False      False    False
# 3       False   False         False     False  False      False    False
# 4       False   False         False     False  False      False    False
# ...       ...     ...           ...       ...    ...        ...      ...
# 18534   False   False         False     False  False      False    False
# 18535   False   False         False     False  False      False    False
# 18536   False   False         False     False  False      False    False
# 18537   False   False         False     False  False      False    False
# 18538   False   False         False     False  False      False    False
#
#        total_pases  regate  finalización  presicion_cabeza  control_balon  \
# ...

# %%
player_nacionalidad = jugadores_2.groupby('nacionalidad').max()
player_club = jugadores_2.groupby('club').max()
player_sprint = jugadores_2.groupby('sprint').max()
# player_name = jugadores_2.groupby('nombre').describe()

# %%
player_nacionalidad.sort_values('altura')
# Out:
#                                nombre  altura  potencia  \
# nacionalidad
# Vietnam              Nguyễn Quang Hải     169        71
# Fiji                       R. Krishna     169        70
# Bermuda                      N. Wells     170        68
# Gibraltar                  T. De Barr     175        65
# São Tomé e Príncipe         Luís Leal     175        67
# ...                               ...     ...       ...
# Wales                     Z. Williams     203        85
# Serbia                    Ž. Živković     203        91
# France                       É. Youan     204        95
# Czech Republic               V. Černý     206        87
# England                 Z. Westbrooke     206        92
#
#                                        club pie_habil  disparo  total_pases  \
# nacionalidad
# Vietnam                              Pau FC     Right       58           60
# Fiji                           Bengaluru FC     Right       69           66
# ...

# %%
player_nacionalidad.sort_values('sprint',ascending=False).head(20)
# Out:
#                           nombre  altura  potencia                       club  \
# nacionalidad
# France                  É. Youan     204        95     İstanbul Başakşehir FK
# Spain              Óscar Whalley     198        93              Śląsk Wrocław
# Netherlands          Z. Flemming     203        92        Yukatel Kayserispor
# Germany                 Ş. Çetin     202        91              Śląsk Wrocław
# Brazil             Élder Santana     200        92  İttifak Holding Konyaspor
# Wales                Z. Williams     203        85          Wycombe Wanderers
# Suriname            Y. Wildschut     192        77                 Venezia FC
# Philippines          R. Obermair     191        74            VfL Bochum 1848
# Norway              Ø. Øvretveit     200        94             Wigan Athletic
# Colombia               Ó. Segura     195        87    Wolverhampton Wanderers
# Ghana                  Y. Yeboah     193        86               İstanbulspor
# ...

# %%
player_sprint = player_sprint.sort_values('sprint',ascending=False)

# %%
player_sprint
# Out:
#                  nombre  altura   nacionalidad  potencia  \
# sprint
# 97            K. Mbappé     182         France        95
# 96            S. Conteh     186          Spain        80
# 95         Vinícius Jr.     185          Wales        92
# 94         T. Hernández     195   Sierra Leone        94
# 93            Z. Sanusi     196    Switzerland        89
# ...                 ...     ...            ...       ...
# 19        V. Lytvynenko     199  United States        74
# 18             W. Lakin     198  United States        81
# 17      Ž. Kostadinović     197        Uruguay        78
# 16              Zhao Bo     201      Venezuela        81
# 15             Y. Boyar     196          Wales        75
#
#                             club pie_habil  disparo  total_pases  regate  \
# sprint
# 97           Paris Saint-Germain     Right       89           80      92
# 96       Wolverhampton Wanderers     Right       65           68      86
# ...

# %%
f, axes = plt.subplots(2, 2, figsize=(15,10), sharex=False)
sns.histplot(jugadores_2["disparo"] , color="skyblue", ax=axes[0, 0])
sns.histplot(jugadores_2["finalización"] , color="olive", ax=axes[0, 1])
sns.histplot(jugadores_2["presicion_cabeza"] , color="gold", ax=axes[1, 0])
sns.histplot(jugadores_2["salto"] , color="teal", ax=axes[1, 1]);

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=player_nacionalidad,
             x="sprint",
             y="reaccion",
             hue="nombre",
            linewidth = 3);

# %%
player_club.sort_values('potencia',ascending=False)
# Out:
#                            nombre  altura         nacionalidad  potencia  \
# club
# Paris Saint-Germain       Vitinha     196                Spain        95
# Manchester City       İ. Gündoğan     195          Switzerland        94
# FC Barcelona          Álvaro Sanz     194              Uruguay        93
# Real Madrid CF       Éder Militão     199              Uruguay        92
# Borussia Dortmund      Y. Moukoko     195        United States        91
# ...                           ...     ...                  ...       ...
# SpVgg Bayreuth           T. Weber     189          Switzerland        68
# SC East Bengal FC    W. Angousana     185                Spain        67
# Finn Harps              É. N'Zeyi     196        United States        66
# NorthEast United FC      T. Singh     189                Spain        65
# Drogheda United          V. Arong     193  Republic of Ireland        64
#
#                     pie_habil  disparo  total_pases  regate  finalización  \
# club
# ...

# %%
player_max.sort_values('potencia')
# Out:
#                      nombre  edad  altura  peso  potencia  \
# nacionalidad
# Barbados        M. Williams    29     185    79        54
# South Sudan         W. Akio    23     188    71        62
# Lebanon           O. Bugiel    28     185    80        63
# Guam           A. DeLaGarza    34     175    68        63
# Mauritius           L. Rose    30     184    79        65
# ...                     ...   ...     ...   ...       ...
# Netherlands     Z. Flemming    39     203    98        92
# Italy             W. Gnonto    44     201    95        92
# Spain         Óscar Whalley    41     198    94        93
# Norway         Ø. Øvretveit    38     200    96        94
# France             É. Youan    41     204    98        95
#
#                                 club pie_habil  ritmo  disparo  total_pases  \
# nacionalidad
# Barbados                Macarthur FC     Right     58       49           52
# South Sudan        Western United FC     Right     76       55           45
# ...

# %%
player_mean.sort_values('altura')
# Out:
#                           edad      altura       peso  potencia      ritmo  \
# nacionalidad
# Fiji                 34.000000  169.000000  70.000000      70.0  90.000000
# Vietnam              25.000000  169.000000  63.000000      71.0  86.000000
# Bermuda              32.000000  170.000000  69.000000      68.0  73.000000
# Dominican Republic   24.666667  172.666667  69.333333      71.0  69.666667
# São Tomé e Príncipe  35.000000  175.000000  80.000000      67.0  69.000000
# ...                        ...         ...        ...       ...        ...
# Lithuania            25.800000  188.400000  78.900000      67.9  66.500000
# Chad                 24.000000  190.000000  85.000000      69.0  72.000000
# Andorra              20.000000  190.000000  78.000000      74.0  61.000000
# Guatemala            25.000000  193.000000  85.000000      68.0  62.000000
# Indonesia            19.000000  194.000000  86.000000      69.0  58.000000
#
# ...

# %%
sprint_10 = sprint_10.groupby('nacionalidad')

# %%
sprint_10.mean()
# Out:
#               edad  altura  peso  potencia  ritmo  disparo  total_pases  \
# nacionalidad
# Brazil        21.0   176.0  73.0      92.0   95.0     79.0         74.0
# France        23.0   182.0  73.0      95.0   97.0     89.0         80.0
# Germany       25.0   178.0  72.0      66.0   95.0     58.0         52.0
# Netherlands   25.0   186.0  76.0      80.0   93.0     58.0         65.0
# Norway        21.0   195.0  94.0      94.0   89.0     91.0         65.0
# Philippines   27.0   185.0  77.0      74.0   94.0     67.0         67.0
# Senegal       24.0   185.0  76.0      83.0   94.0     76.0         67.0
# Spain         26.0   178.0  86.0      80.0   96.0     65.0         68.0
# Suriname      27.0   180.0  77.0      77.0   95.0     75.0         67.0
# Wales         24.0   171.0  76.0      82.0   95.0     70.0         69.0
#
#               regate  defensa  fisico  finalización  presicion_cabeza  volea  \
# nacionalidad
# ...

# %%
sprint_10_max.sort_values('')
# Out:
# <bound method DataFrame.sort_values of                     nombre  edad  altura  peso  potencia  \
# nacionalidad
# Brazil        Vinícius Jr.    21     176    73        92
# France           K. Mbappé    23     182    73        95
# Germany          S. Conteh    25     178    72        66
# Netherlands   J. St. Juste    25     186    76        80
# Norway          E. Haaland    21     195    94        94
# Philippines    G. Holtmann    27     185    77        74
# Senegal            I. Sarr    24     185    76        83
# Spain         Adama Traoré    26     178    86        80
# Suriname         S. Becker    27     180    77        77
# Wales             D. James    24     171    76        82
#
#                                  club pie_habil  ritmo  disparo  total_pases  \
# nacionalidad
# Brazil                 Real Madrid CF     Right     95       79           74
# France            Paris Saint-Germain     Right     97       89           80
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(sprint_10.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %%
sns.pairplot(sprint_10_max,
             kind="ritmo",
             hue="nombre",
             plot_kws=dict(s=80, edgecolor="white",
                           linewidth=2.5));

# %%
plt.figure(figsize=(10,5))
sns.histplot(sprint_10["finalización"],
            # rug=True,
            bins=50)
# plt.xlim(10, 50);
# Out:
# <AxesSubplot:xlabel='finalización', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
sns.distplot(player_median["Potential"],
            rug=True,
            bins=150)
# plt.xlim(10, 50);
# Out:
# C:\Users\varel\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   after removing the cwd from sys.path.
# <AxesSubplot:xlabel='Potential', ylabel='Density'>

# %%
p_0 = np.percentile(jugadores1["sprint"], 0) #Q0 #Min
p_25 = np.percentile(jugadores1["sprint"], 25) #Q1
p_50 = np.percentile(jugadores1["sprint"], 50) #Q2 #Mediana
p_75 = np.percentile(jugadores1["sprint"], 75) #Q3
p_100 = np.percentile(jugadores1["sprint"], 100) #Q4 #Max

print("Valor del percentil 0:", p_0)
print("Valor del percentil 25:", p_25)
print("Valor del percentil 50:", p_50)
print("Valor del percentil 75:", p_75)
print("Valor del percentil 100:", p_100)
print("Valor media:", round(jugadores1["sprint"].median(),2) )
# Out:
# Valor del percentil 0: 15.0
# Valor del percentil 25: 57.0
# Valor del percentil 50: 68.0
# Valor del percentil 75: 75.0
# Valor del percentil 100: 97.0
# Valor media: 64.79

# %%
jugadores1.head()
# Out:
#            nombre  edad  altura  peso nacionalidad  potencia  \
# 0        L. Messi    35     169    67    Argentina        91
# 1      K. Benzema    34     185    81       France        91
# 2  R. Lewandowski    33     185    81       Poland        91
# 3    K. De Bruyne    31     181    70      Belgium        91
# 4       K. Mbappé    23     182    73       France        95
#
#                   club pie_habil  ritmo  disparo  total_pases  regate  \
# 0  Paris Saint-Germain      Left     81       89           90      94
# 1       Real Madrid CF     Right     80       88           83      87
# 2         FC Barcelona     Right     75       91           79      86
# 3      Manchester City     Right     74       88           93      87
# 4  Paris Saint-Germain     Right     97       89           80      92
#
#    defensa  fisico  finalización  presicion_cabeza  volea  control_balon  \
# 0       34      64            90                70     88             93
# ...

# %%
sns.jointplot(x=jugadores1['Finish'],
              y=jugadores1['Potential'],
              kind="hex",
              color="#4CB391");

# %%
play_fifa.corr()
# Out:
#                       Age    Height    Weight  Potential    Growth  \
# Age              1.000000  0.066876  0.218411  -0.262745 -0.862842
# Height           0.066876  1.000000  0.754653   0.018018 -0.021411
# Weight           0.218411  0.754653  1.000000  -0.004111 -0.170711
# Potential       -0.262745  0.018018 -0.004111   1.000000  0.319528
# Growth          -0.862842 -0.021411 -0.170711   0.319528  1.000000
# TotalStats       0.248658 -0.382994 -0.273201   0.369460 -0.340025
# BaseStats        0.385580 -0.123123 -0.014633   0.522793 -0.461013
# ValueEUR         0.032708  0.008377  0.027467   0.530459 -0.096473
# PaceTotal       -0.143984 -0.373660 -0.323965   0.285584  0.013098
# ShootingTotal    0.254601 -0.083714 -0.007235   0.279678 -0.264278
# Pase             0.341518 -0.179531 -0.094253   0.445692 -0.367773
# Regate           0.218045 -0.271181 -0.182494   0.498803 -0.275905
# Defensa          0.227743  0.037012  0.054548   0.177924 -0.250538
# ...

# %%
plt.figure(figsize=(50,35))
sns.heatmap(play_fifa.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %%
plt.figure(figsize=(50,50))
sns.catplot(x="Finish", y="Age", hue="Name", kind="box", data=play_fifa);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...

# %%
play_fifa.head()
# Out:
#              Name  Age  Height  Weight Nationality  Potential  Growth  \
# 0        L. Messi   35     169      67   Argentina         91       0
# 1      K. Benzema   34     185      81      France         91       0
# 2  R. Lewandowski   33     185      81      Poland         91       0
# 3    K. De Bruyne   31     181      70     Belgium         91       0
# 4       K. Mbappé   23     182      73      France         95       4
#
#    TotalStats  BaseStats                 Club   ValueEUR PreferredFoot  Ritmo  \
# 0        2190        452  Paris Saint-Germain   54000000          Left     81
# 1        2147        455       Real Madrid CF   64000000         Right     80
# 2        2205        458         FC Barcelona   84000000         Right     75
# 3        2303        483      Manchester City  107500000         Right     74
# 4        2177        470  Paris Saint-Germain  190500000         Right     97
#
#    ShootingTotal  Pase  Regate  Defensa  Fisico  Finish  HeadingAccuracy  \
# ...
